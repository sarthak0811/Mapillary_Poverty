# %% [markdown]
# # Working Codes

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
# !python /kaggle/input/mapillarygcn/mapillarygcn-master_original/models/run_gcn.py --target pov_label --img_csv /kaggle/input/final-data-csv/final_data_200.csv --train_val_dir /kaggle/input/kenya-mapillary/KE_copy --pretrained_image_file /kaggle/input/cnn-features/pretrained_image_features/resnet34_pretrained_on_imagenet_and_pov.hdf5 --A_type inv --V_type both --lr 1e-6 --batch_size 256 --num_iter 3000

# %%
# !python /kaggle/input/mapillarygcn/mapillarygcn-master/models/run_gcn.py --target pov_label --img_csv /kaggle/input/final-data-csv/final_data_200.csv --train_val_dir /kaggle/input/kenya-mapillary/KE_copy --pretrained_image_file /kaggle/input/cnn-features/pretrained_image_features/resnet34_pretrained_on_imagenet_and_pov.hdf5 --A_type inv --obj_sim cosine --V_type feats --lr 1e-6 --batch_size 256 --num_iter 3000

# %%
# !python /kaggle/input/mapillarygcn/mapillarygcn-master/models/run_gcn.py --target pov_label --img_csv /kaggle/input/final-data-csv/final_data_200.csv --train_val_dir /kaggle/input/kenya-mapillary/KE_copy --pretrained_image_file /kaggle/input/cnn-features/pretrained_image_features/resnet34_pretrained_on_imagenet_and_pov.hdf5 --A_type inv --cluster_limit 10 --V_type both --lr 1e-6 --batch_size 256 --num_iter 3000

# %%
# !python /kaggle/input/mapillaryaug2/mapillarygcn-master/models/run_gcn.py --target pov_label --img_csv /kaggle/input/final-data-csv/final_data_200.csv --train_val_dir /kaggle/input/kenya-mapillary/KE_copy --pretrained_image_file /kaggle/input/cnn-features/pretrained_image_features/resnet34_pretrained_on_imagenet_and_pov.hdf5 --A_type inv --cluster_limit 100 --V_type both --lr 1e-6 --batch_size 256 --num_iter 3000

# %%
# !python /kaggle/input/mapillaryaug/mapillarygcn-master/models/run_gcn.py --target pov_label --img_csv /kaggle/input/final-data-csv/final_data_200.csv --train_val_dir /kaggle/input/kenya-mapillary/KE_copy --pretrained_image_file /kaggle/input/cnn-features/pretrained_image_features/resnet34_pretrained_on_imagenet_and_pov.hdf5 --A_type inv --cluster_limit 50 --V_type both --lr 1e-6 --batch_size 256 --num_iter 3000
# Out:
# ...
# loading presaved graph data...
# Building model...
# Graph size: 200
# 2024-05-10 10:43:54.295434 Padding samples
# Vertices size: (541, 200, 577)
# Adjacency size: (541, 200, 1, 200)
# Labels size: (541,)
# 2024-05-10 10:43:54.295540 Stacking samples
# 2024-05-10 10:43:54.295639 Running CV for: CNN(64)-CNN(64)-GEP(32)-CNN(32)-CNN(32)-GEP(8)-FC(256)-FC(2)
# 2024-05-10 10:43:54.295844 Data ready. no_samples_train: 445 no_samples_test: 96
# 2024-05-10 10:43:54.296547 Training model "mapillary"!
# 2024-05-10 10:43:54.296584 Creating training network
# 2024-05-10 10:43:54.303139 Creating training Tensorflow Tensors
# (445, 200, 577)
# (445, 200, 1, 200)
# (445,)
# (445, 200, 1)
# (445, 200, 577)
# (445, 200, 1, 200)
# (445,)
# (445, 200, 1)
# 2024-05-10 10:43:54.504844 Creating test Tensorflow Tensors
# (96, 200, 577)
# (96, 200, 1, 200)
# (96,)
# (96, 200, 1)
# (96, 200, 577)
# (96, 200, 1, 200)
# (96,)
# (96, 200, 1)
# +++++
# (?, 200, 1, 200)
# (?, 200, 577)
# 64
# 1.0
# +++++
# ...

# %%
# !python /kaggle/input/mapillaryaug/mapillarygcn-master/models/run_gcn.py --target pov_label --img_csv /kaggle/input/final-data-csv/final_data_200.csv --train_val_dir /kaggle/input/kenya-mapillary/KE_copy --pretrained_image_file /kaggle/input/cnn-features/pretrained_image_features/resnet34_pretrained_on_imagenet_and_pov.hdf5 --A_type inv --cluster_limit 72 --V_type both --lr 1e-6 --batch_size 256 --num_iter 3000

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
# !rm -rf /kaggle/working/*

# %%
# !git clone https://github.com/alliajagbe/mapillarygcn
# Out:
# Cloning into 'mapillarygcn'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 117 (delta 14), reused 18 (delta 9), pack-reused 91
# Receiving objects: 100% (117/117), 75.04 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
# !python /kaggle/input/mapillaryhgcn2/archive/mapillarygcn-master/models/run_gcn_version2.py --target pov_label --img_csv /kaggle/input/final-data-csv/final_data_200.csv --train_val_dir /kaggle/input/kenya-mapillary/KE_copy --pretrained_image_file /kaggle/input/cnn-features/pretrained_image_features/resnet34_pretrained_on_imagenet_and_pov.hdf5 --A_type inv --cluster_limit 100 --V_type both --lr 1e-6 --batch_size 256 --num_iter 3000
